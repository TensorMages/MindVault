# %% [raw]
# ---
# description: This module reads the Chrome Bookmarks from all profiles and returns
#   a list of bookmarks.
# output-file: chrome_bookmarks.html
# title: Reading Chrome Bookmarks from all profiles
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
# TODO: Make basebrowser class

# %%
#| echo: false
#| output: asis
show_doc(ChromeBookmarks)
# Out:
# ---
#
# ### ChromeBookmarks
#
# >      ChromeBookmarks ()
#
# *A class to interact with Chrome Bookmarks.*

# %%
#| echo: false
#| output: asis
show_doc(ChromeBookmarks.get_chrome_bookmarks_files)
# Out:
# ---
#
# ### ChromeBookmarks.get_chrome_bookmarks_files
#
# >      ChromeBookmarks.get_chrome_bookmarks_files ()

# %%
#| echo: false
#| output: asis
show_doc(BookmarkModel)
# Out:
# ---
#
# ### BookmarkModel
#
# >      BookmarkModel (name:str, url:str, folder:str, date_added:datetime.date)
#
# *A model representing a bookmark.*

# %%
#| echo: false
#| output: asis
show_doc(windows_epoch_to_datetime)
# Out:
# ---
#
# ### windows_epoch_to_datetime
#
# >      windows_epoch_to_datetime (windows_timestamp)
#
# *Convert Windows epoch timestamp to datetime object.*

# %%
#| echo: false
#| output: asis
show_doc(ChromeBookmarks.extract_bookmark_info)
# Out:
# ---
#
# ### ChromeBookmarks.extract_bookmark_info
#
# >      ChromeBookmarks.extract_bookmark_info (bookmarks_file_path:str)
#
# *Extracts bookmark information from a Chrome Bookmarks file.*
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | bookmarks_file_path | str | path to the bookmarks file |
# | **Returns** | **list** |  |

# %%
#| echo: false
#| output: asis
show_doc(ChromeBookmarks.extract_all_chrome_bookmarks)
# Out:
# ---
#
# ### ChromeBookmarks.extract_all_chrome_bookmarks
#
# >      ChromeBookmarks.extract_all_chrome_bookmarks ()
#
# *Extracts all Chrome Bookmarks from all profiles.*
