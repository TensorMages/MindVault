# %% [raw]
# ---
# description: AI-powered personal knowledge assistant that transforms your digital
#   footprint into an intelligent knowledge base.
# output-file: index.html
# title: MindVault
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Install

# %% [markdown]
# ```sh
# pip install MindVault
# ```

# %% [markdown]
# ## How to use
