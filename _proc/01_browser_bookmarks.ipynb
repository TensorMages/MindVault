# %% [raw]
# ---
# description: Extracting and storing bookmarks from potentially all kind of browsers
#   (currently chrome and edge supported)
# output-file: browser_bookmarks.html
# title: Extracting browser bookmarks
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# Schema of how the bookmarks shall be stored:

# %%
#| echo: false
#| output: asis
show_doc(BookmarkModel)
# Out:
# ---
#
# [source](https://github.com/TensorMages/MindVault/blob/main/MindVault/bookmarks/browser/chrome_bookmarks.py#L59){target="_blank" style="float:right; font-size:smaller"}
#
# ### BookmarkModel
#
# >      BookmarkModel (name:str, url:str, folder:str, date_added:datetime.date)
#
# *A model representing a bookmark.*

# %% [markdown]
# Browser base model (to be inherited by all supported browsers)

# %%
#| echo: false
#| output: asis
show_doc(BaseBrowser)
# Out:
# ---
#
# [source](https://github.com/TensorMages/MindVault/blob/main/MindVault/bookmarks/browser/broswe_bookmarks_handler.py#L37){target="_blank" style="float:right; font-size:smaller"}
#
# ### BaseBrowser
#
# >      BaseBrowser (name:str, user_data_paths:Dict[str,str],
# >                   bookmarks_file_name:str,
# >                   operating_system:Optional[str]=None,
# >                   user_data_dir_path:Optional[pathlib.Path]=None)
#
# *Base class for interacting with web browsers' bookmarks*

# %% [markdown]
# Functions of class [`BaseBrowser`](https://TensorMages.github.io/MindVault/browser_bookmarks.html#basebrowser) must be over-ridden by child classes, if for some browser different handling of bookmarks is required :/

# %% [markdown]
# Chrome browser:

# %%
#| echo: false
#| output: asis
show_doc(ChromeBrowser)
# Out:
# ---
#
# [source](https://github.com/TensorMages/MindVault/blob/main/MindVault/bookmarks/browser/broswe_bookmarks_handler.py#L124){target="_blank" style="float:right; font-size:smaller"}
#
# ### ChromeBrowser
#
# >      ChromeBrowser (name:str='Chrome',
# >                     user_data_paths:Dict[str,str]={'Windows':
# >                     '~\\AppData\\Local\\Google\\Chrome\\User Data', 'Mac':
# >                     '~/Library/Application Support/Google/Chrome', 'Linux':
# >                     '~/.config/google-chrome'},
# >                     bookmarks_file_name:str='Bookmarks',
# >                     operating_system:Optional[str]=None,
# >                     user_data_dir_path:Optional[pathlib.Path]=None)
#
# *Base class for interacting with web browsers' bookmarks*

# %% [markdown]
# Seeing if it works fine:

# %%
chrome = ChromeBrowser()

print(f"{chrome.name} Bookmarks:")
for bookmark in chrome.extract_bookmarks():
    print(bookmark)

# %% [markdown]
# Edge browser:

# %%
#| echo: false
#| output: asis
show_doc(EdgeBrowser)
# Out:
# ---
#
# [source](https://github.com/TensorMages/MindVault/blob/main/MindVault/bookmarks/browser/broswe_bookmarks_handler.py#L134){target="_blank" style="float:right; font-size:smaller"}
#
# ### EdgeBrowser
#
# >      EdgeBrowser (name:str='Microsoft Edge',
# >                   user_data_paths:Dict[str,str]={'Windows':
# >                   '~\\AppData\\Local\\Microsoft\\Edge\\User Data', 'Mac':
# >                   '~/Library/Application Support/Microsoft Edge', 'Linux':
# >                   '~/.config/microsoft-edge'},
# >                   bookmarks_file_name:str='Bookmarks',
# >                   operating_system:Optional[str]=None,
# >                   user_data_dir_path:Optional[pathlib.Path]=None)
#
# *Base class for interacting with web browsers' bookmarks*

# %%
edge = EdgeBrowser()

print(f"{edge.name} Bookmarks:")
for bookmark in edge.extract_bookmarks():
    print(bookmark)

# %% [markdown]
# Brave:

# %%
class BraveBrowser(BaseBrowser):
    name: str = "Brave"
    user_data_paths: Dict[str, str] = {
        "Windows": r"~\AppData\Local\BraveSoftware\Brave-Browser",
        "Mac": r"~/Library/Application Support/BraveSoftware/Brave-Browser",
        "Linux": r"~/.config/BraveSoftware/Brave-Browser"
    }
    bookmarks_file_name: str = "Bookmarks"
